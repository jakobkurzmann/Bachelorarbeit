# %%
# %pip install neo4j
# %pip install graphdatascience
# %pip install numpy

# %%
import numpy as np
import random
import datetime
from neo4j import GraphDatabase
import graphdatascience
# Out:
# /Users/jakobkurzmann/Library/Python/3.9/lib/python/site-packages/urllib3/__init__.py:35: NotOpenSSLWarning: urllib3 v2 only supports OpenSSL 1.1.1+, currently the 'ssl' module is compiled with 'LibreSSL 2.8.3'. See: https://github.com/urllib3/urllib3/issues/3020
#   warnings.warn(

# %%
endpoint = "neo4j://localhost:7687"
username = "neo4j"
password = "#Bachelorarbeit"
database = "neo4j"

gds = graphdatascience.GraphDataScience(endpoint=endpoint, auth=(username, password))
gds.set_database(database)

db_driver = GraphDatabase.driver(endpoint, auth=(username,password))

# %%
def random_timestamp_for_station(station_id, suffix="start"):
    random.seed(f"{station_id}_{suffix}")  # unterscheidet start und endzeitpunkt für den randomseed damit ergebnis reproduzierbar ist

    year = 2017
    month = random.randint(1, 12)
    day = random.randint(1, 28)
    hour = random.randint(0, 23)
    minute = random.randint(0, 59)
    second = random.randint(0, 59)

    return datetime.datetime(year, month, day, hour, minute, second)

# %%
def write_station_embeddings_batchwise(driver, batch_size=500):
    with driver.session(database=database) as session:
        result = session.run("""
            MATCH (s:Station)
            RETURN id(s) AS station_id
        """)

        batch = []
        count = 0
        for record in result:
            sid = record["station_id"]

            try:
                start_dt = random_timestamp_for_station(sid, "start")
                end_dt = random_timestamp_for_station(sid, "end")

                startTimeStation_emb = timestamp_to_embedding(start_dt)
                endTimeStation_emb = timestamp_to_embedding(end_dt)

                batch.append({
                    "station_id": sid,
                    "start": startTimeStation_emb.tolist(),
                    "end": endTimeStation_emb.tolist()
                })

            except Exception as e:
                print(f"Skipping station {sid}: {e}")

            if len(batch) >= batch_size:
                _send_station_embedding_batch(driver, batch)
                count += len(batch)
                print(f"{count} stations processed.")
                batch = []

        if batch:
            _send_station_embedding_batch(driver, batch)

def _send_station_embedding_batch(driver, batch):
    query = """
    CALL apoc.periodic.iterate(
      'UNWIND $batch AS row RETURN row',
      '
      MATCH (s:Station) WHERE id(s) = row.station_id
      SET s.startTimeEmbedding = row.start,
          s.endTimeEmbedding = row.end
      ',
      {batchSize: 100, parallel: true, params: {batch: $batch}}
    )
    """
    with driver.session(database=database) as session:
        session.run(query, batch=batch)


write_station_embeddings_batchwise(db_driver)

# %%
def timestamp_to_embedding(timestamp):
    try:
        d = timestamp.to_native()  # für Neo4j-Typen
    except AttributeError:
        d = timestamp # für stationsembedding

    unix_timestamp = int(d.timestamp())
    dt = datetime.datetime.fromtimestamp(unix_timestamp)

    hour_sin = np.sin(2* np.pi * dt.hour /24)
    hour_cos = np.cos(2* np.pi * dt.hour /24)

    weekday_sin = np.sin(2* np.pi * dt.weekday() / 7)
    weekday_cos = np.cos(2* np.pi * dt.weekday() / 7)

    day_sin = np.sin(2* np.pi * dt.day / 7)
    day_cos = np.cos(2* np.pi * dt.day / 7)

    month_sin = np.sin(2* np.pi * dt.month / 12)
    month_cos = np.cos(2* np.pi * dt.month / 12)

    is_weekend = 1 if dt.weekday() >5 else 0

    day_of_year = d.timetuple().tm_yday
    unix_scaled = unix_timestamp / 1e9


    return np.array([hour_sin, hour_cos, weekday_sin, weekday_cos, day_sin, day_cos,month_sin, month_cos, is_weekend, day_of_year, unix_scaled])

# %%
#52 min
def write_embeddings_batchwise(driver, batch_size=500):
    with driver.session(database=database) as session:
        result = session.run("""
            MATCH (t:Trip)
            WHERE t.validFrom IS NOT NULL AND t.validTo IS NOT NULL
            RETURN id(t) AS node_id, t.validFrom AS startTime, t.validTo AS endTime
        """)

        batch = []
        batches_sent = 0
        for record in result:
            try:
                timeEmbeddingStart = timestamp_to_embedding(record["startTime"])
                timeEmbeddingEnd = timestamp_to_embedding(record["endTime"])
                batch.append({
                    "node_id": record["node_id"],
                    "externalTimeEmbeddingStart": timeEmbeddingStart.tolist(),
                    "externalTimeEmbeddingEnd": timeEmbeddingEnd.tolist()
                })
            except Exception as e:
                print(f"Skipping node {record['node_id']}: {e}")

            if len(batch) >= batch_size:
                _send_embedding_batch(driver, batch)
                batches_sent += batch_size
                print(f"{batches_sent} embeddings geschrieben")
                batch = []

        if batch:
            _send_embedding_batch(driver, batch)

def _send_embedding_batch(driver, batch):
    query = """
    CALL apoc.periodic.iterate(
      'UNWIND $batch AS row RETURN row',
      '
      MATCH (t:Trip) WHERE id(t) = row.node_id
      SET t.startTimeEmbedding = row.externalTimeEmbeddingStart,
          t.endTimeEmbedding = row.externalTimeEmbeddingEnd
      ',
      {batchSize: 100, parallel: true, params: {batch: $batch}}
    )
    """
    with driver.session(database=database) as session:
        session.run(query, batch=batch)

write_embeddings_batchwise(db_driver)
# Out:
# 500 embeddings geschrieben
# 1000 embeddings geschrieben
# 1500 embeddings geschrieben
# 2000 embeddings geschrieben
# 2500 embeddings geschrieben
# 3000 embeddings geschrieben
# 3500 embeddings geschrieben
# 4000 embeddings geschrieben
# 4500 embeddings geschrieben
# 5000 embeddings geschrieben
# 5500 embeddings geschrieben
# 6000 embeddings geschrieben
# 6500 embeddings geschrieben
# 7000 embeddings geschrieben
# 7500 embeddings geschrieben
# 8000 embeddings geschrieben
# 8500 embeddings geschrieben
# 9000 embeddings geschrieben
# 9500 embeddings geschrieben
# 10000 embeddings geschrieben
# 10500 embeddings geschrieben
# 11000 embeddings geschrieben
# 11500 embeddings geschrieben
# 12000 embeddings geschrieben
# 12500 embeddings geschrieben
# 13000 embeddings geschrieben
# 13500 embeddings geschrieben
# 14000 embeddings geschrieben
# 14500 embeddings geschrieben
# 15000 embeddings geschrieben
# 15500 embeddings geschrieben
# 16000 embeddings geschrieben
# 16500 embeddings geschrieben
# 17000 embeddings geschrieben
# 17500 embeddings geschrieben
# 18000 embeddings geschrieben
# 18500 embeddings geschrieben
# 19000 embeddings geschrieben
# 19500 embeddings geschrieben
# 20000 embeddings geschrieben
# 20500 embeddings geschrieben
# 21000 embeddings geschrieben
# 21500 embeddings geschrieben
# 22000 embeddings geschrieben
# 22500 embeddings geschrieben
# 23000 embeddings geschrieben
# 23500 embeddings geschrieben
# 24000 embeddings geschrieben
# 24500 embeddings geschrieben
# 25000 embeddings geschrieben
# 25500 embeddings geschrieben
# 26000 embeddings geschrieben
# 26500 embeddings geschrieben
# 27000 embeddings geschrieben
# 27500 embeddings geschrieben
# 28000 embeddings geschrieben
# 28500 embeddings geschrieben
# 29000 embeddings geschrieben
# 29500 embeddings geschrieben
# 30000 embeddings geschrieben
# 30500 embeddings geschrieben
# 31000 embeddings geschrieben
# 31500 embeddings geschrieben
# 32000 embeddings geschrieben
# 32500 embeddings geschrieben
# 33000 embeddings geschrieben
# 33500 embeddings geschrieben
# 34000 embeddings geschrieben
# 34500 embeddings geschrieben
# 35000 embeddings geschrieben
# 35500 embeddings geschrieben
# 36000 embeddings geschrieben
# 36500 embeddings geschrieben
# 37000 embeddings geschrieben
# 37500 embeddings geschrieben
# 38000 embeddings geschrieben
# 38500 embeddings geschrieben
# 39000 embeddings geschrieben
# 39500 embeddings geschrieben
# 40000 embeddings geschrieben
# 40500 embeddings geschrieben
# 41000 embeddings geschrieben
# 41500 embeddings geschrieben
# 42000 embeddings geschrieben
# 42500 embeddings geschrieben
# 43000 embeddings geschrieben
# 43500 embeddings geschrieben
# 44000 embeddings geschrieben
# 44500 embeddings geschrieben
# 45000 embeddings geschrieben
# 45500 embeddings geschrieben
# 46000 embeddings geschrieben
# 46500 embeddings geschrieben
# 47000 embeddings geschrieben
# 47500 embeddings geschrieben
# 48000 embeddings geschrieben
# 48500 embeddings geschrieben
# 49000 embeddings geschrieben
# 49500 embeddings geschrieben
# 50000 embeddings geschrieben
# 50500 embeddings geschrieben
# 51000 embeddings geschrieben
# 51500 embeddings geschrieben
# 52000 embeddings geschrieben
# 52500 embeddings geschrieben
# 53000 embeddings geschrieben
# 53500 embeddings geschrieben
# 54000 embeddings geschrieben
# 54500 embeddings geschrieben
# 55000 embeddings geschrieben
# 55500 embeddings geschrieben
# 56000 embeddings geschrieben
# 56500 embeddings geschrieben
# 57000 embeddings geschrieben
# 57500 embeddings geschrieben
# 58000 embeddings geschrieben
# 58500 embeddings geschrieben
# 59000 embeddings geschrieben
# 59500 embeddings geschrieben
# 60000 embeddings geschrieben
# 60500 embeddings geschrieben
# 61000 embeddings geschrieben
# 61500 embeddings geschrieben
# 62000 embeddings geschrieben
# 62500 embeddings geschrieben
# 63000 embeddings geschrieben
# 63500 embeddings geschrieben
# 64000 embeddings geschrieben
# 64500 embeddings geschrieben
# 65000 embeddings geschrieben
# 65500 embeddings geschrieben
# 66000 embeddings geschrieben
# 66500 embeddings geschrieben
# 67000 embeddings geschrieben
# 67500 embeddings geschrieben
# 68000 embeddings geschrieben
# 68500 embeddings geschrieben
# 69000 embeddings geschrieben
# 69500 embeddings geschrieben
# 70000 embeddings geschrieben
# 70500 embeddings geschrieben
# 71000 embeddings geschrieben
# 71500 embeddings geschrieben
# 72000 embeddings geschrieben
# 72500 embeddings geschrieben
# 73000 embeddings geschrieben
# 73500 embeddings geschrieben
# 74000 embeddings geschrieben
# 74500 embeddings geschrieben
# 75000 embeddings geschrieben
# 75500 embeddings geschrieben
# 76000 embeddings geschrieben
# 76500 embeddings geschrieben
# 77000 embeddings geschrieben
# 77500 embeddings geschrieben
# 78000 embeddings geschrieben
# 78500 embeddings geschrieben
# 79000 embeddings geschrieben
# 79500 embeddings geschrieben
# 80000 embeddings geschrieben
# 80500 embeddings geschrieben
# 81000 embeddings geschrieben
# 81500 embeddings geschrieben
# 82000 embeddings geschrieben
# 82500 embeddings geschrieben
# 83000 embeddings geschrieben
# 83500 embeddings geschrieben
# 84000 embeddings geschrieben
# 84500 embeddings geschrieben
# 85000 embeddings geschrieben
# 85500 embeddings geschrieben
# 86000 embeddings geschrieben
# 86500 embeddings geschrieben
# 87000 embeddings geschrieben
# 87500 embeddings geschrieben
# 88000 embeddings geschrieben
# 88500 embeddings geschrieben
# 89000 embeddings geschrieben
# 89500 embeddings geschrieben
# 90000 embeddings geschrieben
# 90500 embeddings geschrieben
# 91000 embeddings geschrieben
# 91500 embeddings geschrieben
# 92000 embeddings geschrieben
# 92500 embeddings geschrieben
# 93000 embeddings geschrieben
# 93500 embeddings geschrieben
# 94000 embeddings geschrieben
# 94500 embeddings geschrieben
# 95000 embeddings geschrieben
# 95500 embeddings geschrieben
# 96000 embeddings geschrieben
# 96500 embeddings geschrieben
# 97000 embeddings geschrieben
# 97500 embeddings geschrieben
# 98000 embeddings geschrieben
# 98500 embeddings geschrieben
# 99000 embeddings geschrieben
# 99500 embeddings geschrieben
# 100000 embeddings geschrieben
# 100500 embeddings geschrieben
# 101000 embeddings geschrieben
# 101500 embeddings geschrieben
# 102000 embeddings geschrieben
# 102500 embeddings geschrieben
# 103000 embeddings geschrieben
# 103500 embeddings geschrieben
# 104000 embeddings geschrieben
# 104500 embeddings geschrieben
# 105000 embeddings geschrieben
# 105500 embeddings geschrieben
# 106000 embeddings geschrieben
# 106500 embeddings geschrieben
# 107000 embeddings geschrieben
# 107500 embeddings geschrieben
# 108000 embeddings geschrieben
# 108500 embeddings geschrieben
# 109000 embeddings geschrieben
# 109500 embeddings geschrieben
# 110000 embeddings geschrieben
# 110500 embeddings geschrieben
# 111000 embeddings geschrieben
# 111500 embeddings geschrieben
# 112000 embeddings geschrieben
# 112500 embeddings geschrieben
# 113000 embeddings geschrieben
# 113500 embeddings geschrieben
# 114000 embeddings geschrieben
# 114500 embeddings geschrieben
# 115000 embeddings geschrieben
# 115500 embeddings geschrieben
# 116000 embeddings geschrieben
# 116500 embeddings geschrieben
# 117000 embeddings geschrieben
# 117500 embeddings geschrieben
# 118000 embeddings geschrieben
# 118500 embeddings geschrieben
# 119000 embeddings geschrieben
# 119500 embeddings geschrieben
# 120000 embeddings geschrieben
# 120500 embeddings geschrieben
# 121000 embeddings geschrieben
# 121500 embeddings geschrieben
# 122000 embeddings geschrieben
# 122500 embeddings geschrieben
# 123000 embeddings geschrieben
# 123500 embeddings geschrieben
# 124000 embeddings geschrieben
# 124500 embeddings geschrieben
# 125000 embeddings geschrieben
# 125500 embeddings geschrieben
# 126000 embeddings geschrieben
# 126500 embeddings geschrieben
# 127000 embeddings geschrieben
# 127500 embeddings geschrieben
# 128000 embeddings geschrieben
# 128500 embeddings geschrieben
# 129000 embeddings geschrieben
# 129500 embeddings geschrieben
# 130000 embeddings geschrieben
# 130500 embeddings geschrieben
# 131000 embeddings geschrieben
# 131500 embeddings geschrieben
# 132000 embeddings geschrieben
# 132500 embeddings geschrieben
# 133000 embeddings geschrieben
# 133500 embeddings geschrieben
# 134000 embeddings geschrieben
# 134500 embeddings geschrieben
# 135000 embeddings geschrieben
# 135500 embeddings geschrieben
# 136000 embeddings geschrieben
# 136500 embeddings geschrieben
# 137000 embeddings geschrieben
# 137500 embeddings geschrieben
# 138000 embeddings geschrieben
# 138500 embeddings geschrieben
# 139000 embeddings geschrieben
# 139500 embeddings geschrieben
# 140000 embeddings geschrieben
# 140500 embeddings geschrieben
# 141000 embeddings geschrieben
# 141500 embeddings geschrieben
# 142000 embeddings geschrieben
# 142500 embeddings geschrieben
# 143000 embeddings geschrieben
# 143500 embeddings geschrieben
# 144000 embeddings geschrieben
# 144500 embeddings geschrieben
# 145000 embeddings geschrieben
# 145500 embeddings geschrieben
# 146000 embeddings geschrieben
# 146500 embeddings geschrieben
# 147000 embeddings geschrieben
# 147500 embeddings geschrieben
# 148000 embeddings geschrieben
# 148500 embeddings geschrieben
# 149000 embeddings geschrieben
# 149500 embeddings geschrieben
# 150000 embeddings geschrieben
# 150500 embeddings geschrieben
# 151000 embeddings geschrieben
# 151500 embeddings geschrieben
# 152000 embeddings geschrieben
# 152500 embeddings geschrieben
# 153000 embeddings geschrieben
# 153500 embeddings geschrieben
# 154000 embeddings geschrieben
# 154500 embeddings geschrieben
# 155000 embeddings geschrieben
# 155500 embeddings geschrieben
# 156000 embeddings geschrieben
# 156500 embeddings geschrieben
# 157000 embeddings geschrieben
# 157500 embeddings geschrieben
# 158000 embeddings geschrieben
# 158500 embeddings geschrieben
# 159000 embeddings geschrieben
# 159500 embeddings geschrieben
# 160000 embeddings geschrieben
# 160500 embeddings geschrieben
# 161000 embeddings geschrieben
# 161500 embeddings geschrieben
# 162000 embeddings geschrieben
# 162500 embeddings geschrieben
# 163000 embeddings geschrieben
# 163500 embeddings geschrieben
# 164000 embeddings geschrieben
# 164500 embeddings geschrieben
# 165000 embeddings geschrieben
# 165500 embeddings geschrieben
# 166000 embeddings geschrieben
# 166500 embeddings geschrieben
# 167000 embeddings geschrieben
# 167500 embeddings geschrieben
# 168000 embeddings geschrieben
# 168500 embeddings geschrieben
# 169000 embeddings geschrieben
# 169500 embeddings geschrieben
# 170000 embeddings geschrieben
# 170500 embeddings geschrieben
# 171000 embeddings geschrieben
# 171500 embeddings geschrieben
# 172000 embeddings geschrieben
# 172500 embeddings geschrieben
# 173000 embeddings geschrieben
# 173500 embeddings geschrieben
# 174000 embeddings geschrieben
# 174500 embeddings geschrieben
# 175000 embeddings geschrieben
# 175500 embeddings geschrieben
# 176000 embeddings geschrieben
# 176500 embeddings geschrieben
# 177000 embeddings geschrieben
# 177500 embeddings geschrieben
# 178000 embeddings geschrieben
# 178500 embeddings geschrieben
# 179000 embeddings geschrieben
# 179500 embeddings geschrieben
# 180000 embeddings geschrieben
# 180500 embeddings geschrieben
# 181000 embeddings geschrieben
# 181500 embeddings geschrieben
# 182000 embeddings geschrieben
# 182500 embeddings geschrieben
# 183000 embeddings geschrieben
# 183500 embeddings geschrieben
# 184000 embeddings geschrieben
# 184500 embeddings geschrieben
# 185000 embeddings geschrieben
# 185500 embeddings geschrieben
# 186000 embeddings geschrieben
# 186500 embeddings geschrieben
# 187000 embeddings geschrieben
# 187500 embeddings geschrieben
# 188000 embeddings geschrieben
# 188500 embeddings geschrieben
# 189000 embeddings geschrieben
# 189500 embeddings geschrieben
# 190000 embeddings geschrieben
# 190500 embeddings geschrieben
# 191000 embeddings geschrieben
# 191500 embeddings geschrieben
# 192000 embeddings geschrieben
# 192500 embeddings geschrieben
# 193000 embeddings geschrieben
# 193500 embeddings geschrieben
# 194000 embeddings geschrieben
# 194500 embeddings geschrieben
# 195000 embeddings geschrieben
# 195500 embeddings geschrieben
# 196000 embeddings geschrieben
# 196500 embeddings geschrieben
# 197000 embeddings geschrieben
# 197500 embeddings geschrieben
# 198000 embeddings geschrieben
# 198500 embeddings geschrieben
# 199000 embeddings geschrieben
# 199500 embeddings geschrieben
# 200000 embeddings geschrieben
# 200500 embeddings geschrieben
# 201000 embeddings geschrieben
# 201500 embeddings geschrieben
# 202000 embeddings geschrieben
# 202500 embeddings geschrieben
# 203000 embeddings geschrieben
# 203500 embeddings geschrieben
# 204000 embeddings geschrieben
# 204500 embeddings geschrieben
# 205000 embeddings geschrieben
# 205500 embeddings geschrieben
# 206000 embeddings geschrieben
# 206500 embeddings geschrieben
# 207000 embeddings geschrieben
# 207500 embeddings geschrieben
# 208000 embeddings geschrieben
# 208500 embeddings geschrieben
# 209000 embeddings geschrieben
# 209500 embeddings geschrieben
# 210000 embeddings geschrieben
# 210500 embeddings geschrieben
# 211000 embeddings geschrieben
# 211500 embeddings geschrieben
# 212000 embeddings geschrieben
# 212500 embeddings geschrieben
# 213000 embeddings geschrieben
# 213500 embeddings geschrieben
# 214000 embeddings geschrieben
# 214500 embeddings geschrieben
# 215000 embeddings geschrieben
# 215500 embeddings geschrieben
# 216000 embeddings geschrieben
# 216500 embeddings geschrieben
# 217000 embeddings geschrieben
# 217500 embeddings geschrieben
# 218000 embeddings geschrieben
# 218500 embeddings geschrieben
# 219000 embeddings geschrieben
# 219500 embeddings geschrieben
# 220000 embeddings geschrieben
# 220500 embeddings geschrieben
# 221000 embeddings geschrieben
# 221500 embeddings geschrieben
# 222000 embeddings geschrieben
# 222500 embeddings geschrieben
# 223000 embeddings geschrieben
# 223500 embeddings geschrieben
# 224000 embeddings geschrieben
# 224500 embeddings geschrieben
# 225000 embeddings geschrieben
# 225500 embeddings geschrieben
# 226000 embeddings geschrieben
# 226500 embeddings geschrieben
# 227000 embeddings geschrieben
# 227500 embeddings geschrieben
# 228000 embeddings geschrieben
# 228500 embeddings geschrieben
# 229000 embeddings geschrieben
# 229500 embeddings geschrieben
# 230000 embeddings geschrieben
# 230500 embeddings geschrieben
# 231000 embeddings geschrieben
# 231500 embeddings geschrieben
# 232000 embeddings geschrieben
# 232500 embeddings geschrieben
# 233000 embeddings geschrieben
# 233500 embeddings geschrieben
# 234000 embeddings geschrieben
# 234500 embeddings geschrieben
# 235000 embeddings geschrieben
# 235500 embeddings geschrieben
# 236000 embeddings geschrieben
# 236500 embeddings geschrieben
# 237000 embeddings geschrieben
# 237500 embeddings geschrieben
# 238000 embeddings geschrieben
# 238500 embeddings geschrieben
# 239000 embeddings geschrieben
# 239500 embeddings geschrieben
# 240000 embeddings geschrieben
# 240500 embeddings geschrieben
# 241000 embeddings geschrieben
# 241500 embeddings geschrieben
# 242000 embeddings geschrieben
# 242500 embeddings geschrieben
# 243000 embeddings geschrieben
# 243500 embeddings geschrieben
# 244000 embeddings geschrieben
# 244500 embeddings geschrieben
# 245000 embeddings geschrieben
# 245500 embeddings geschrieben
# 246000 embeddings geschrieben
# 246500 embeddings geschrieben
# 247000 embeddings geschrieben
# 247500 embeddings geschrieben
# 248000 embeddings geschrieben
# 248500 embeddings geschrieben
# 249000 embeddings geschrieben
# 249500 embeddings geschrieben
# 250000 embeddings geschrieben
# 250500 embeddings geschrieben
# 251000 embeddings geschrieben
# 251500 embeddings geschrieben
# 252000 embeddings geschrieben
# 252500 embeddings geschrieben
# 253000 embeddings geschrieben
# 253500 embeddings geschrieben
# 254000 embeddings geschrieben
# 254500 embeddings geschrieben
# 255000 embeddings geschrieben
# 255500 embeddings geschrieben
# 256000 embeddings geschrieben
# 256500 embeddings geschrieben
# 257000 embeddings geschrieben
# 257500 embeddings geschrieben
# 258000 embeddings geschrieben
# 258500 embeddings geschrieben
# 259000 embeddings geschrieben
# 259500 embeddings geschrieben
# 260000 embeddings geschrieben
# 260500 embeddings geschrieben
# 261000 embeddings geschrieben
# 261500 embeddings geschrieben
# 262000 embeddings geschrieben
# 262500 embeddings geschrieben
# 263000 embeddings geschrieben
# 263500 embeddings geschrieben
# 264000 embeddings geschrieben
# 264500 embeddings geschrieben
# 265000 embeddings geschrieben
# 265500 embeddings geschrieben
# 266000 embeddings geschrieben
# 266500 embeddings geschrieben
# 267000 embeddings geschrieben
# 267500 embeddings geschrieben
# 268000 embeddings geschrieben
# 268500 embeddings geschrieben
# 269000 embeddings geschrieben
# 269500 embeddings geschrieben
# 270000 embeddings geschrieben
# 270500 embeddings geschrieben
# 271000 embeddings geschrieben
# 271500 embeddings geschrieben
# 272000 embeddings geschrieben
# 272500 embeddings geschrieben
# 273000 embeddings geschrieben
# 273500 embeddings geschrieben
# 274000 embeddings geschrieben
# 274500 embeddings geschrieben
# 275000 embeddings geschrieben
# 275500 embeddings geschrieben
# 276000 embeddings geschrieben
# 276500 embeddings geschrieben
# 277000 embeddings geschrieben
# 277500 embeddings geschrieben
# 278000 embeddings geschrieben
# 278500 embeddings geschrieben
# 279000 embeddings geschrieben
# 279500 embeddings geschrieben
# 280000 embeddings geschrieben
# 280500 embeddings geschrieben
# 281000 embeddings geschrieben
# 281500 embeddings geschrieben
# 282000 embeddings geschrieben
# 282500 embeddings geschrieben
# 283000 embeddings geschrieben
# 283500 embeddings geschrieben
# 284000 embeddings geschrieben
# 284500 embeddings geschrieben
# 285000 embeddings geschrieben
# 285500 embeddings geschrieben
# 286000 embeddings geschrieben
# 286500 embeddings geschrieben
# 287000 embeddings geschrieben
# 287500 embeddings geschrieben
# 288000 embeddings geschrieben
# 288500 embeddings geschrieben
# 289000 embeddings geschrieben
# 289500 embeddings geschrieben
# 290000 embeddings geschrieben
# 290500 embeddings geschrieben
# 291000 embeddings geschrieben
# 291500 embeddings geschrieben
# 292000 embeddings geschrieben
# 292500 embeddings geschrieben
# 293000 embeddings geschrieben
# 293500 embeddings geschrieben
# 294000 embeddings geschrieben
# 294500 embeddings geschrieben
# 295000 embeddings geschrieben
# 295500 embeddings geschrieben
# 296000 embeddings geschrieben
# 296500 embeddings geschrieben
# 297000 embeddings geschrieben
# 297500 embeddings geschrieben
# 298000 embeddings geschrieben
# 298500 embeddings geschrieben
# 299000 embeddings geschrieben
# 299500 embeddings geschrieben
# 300000 embeddings geschrieben
# 300500 embeddings geschrieben
# 301000 embeddings geschrieben
# 301500 embeddings geschrieben
# 302000 embeddings geschrieben
# 302500 embeddings geschrieben
# 303000 embeddings geschrieben
# 303500 embeddings geschrieben
# 304000 embeddings geschrieben
# 304500 embeddings geschrieben
# 305000 embeddings geschrieben
# 305500 embeddings geschrieben
# 306000 embeddings geschrieben
# 306500 embeddings geschrieben
# 307000 embeddings geschrieben
# 307500 embeddings geschrieben
# 308000 embeddings geschrieben
# 308500 embeddings geschrieben
# 309000 embeddings geschrieben
# 309500 embeddings geschrieben
# 310000 embeddings geschrieben
# 310500 embeddings geschrieben
# 311000 embeddings geschrieben
# 311500 embeddings geschrieben
# 312000 embeddings geschrieben
# 312500 embeddings geschrieben
# 313000 embeddings geschrieben
# 313500 embeddings geschrieben
# 314000 embeddings geschrieben
# 314500 embeddings geschrieben
# 315000 embeddings geschrieben
# 315500 embeddings geschrieben
# 316000 embeddings geschrieben
# 316500 embeddings geschrieben
# 317000 embeddings geschrieben
# 317500 embeddings geschrieben
# 318000 embeddings geschrieben
# 318500 embeddings geschrieben
# 319000 embeddings geschrieben
# 319500 embeddings geschrieben
# 320000 embeddings geschrieben
# 320500 embeddings geschrieben
# 321000 embeddings geschrieben
# 321500 embeddings geschrieben
# 322000 embeddings geschrieben
# 322500 embeddings geschrieben
# 323000 embeddings geschrieben
# 323500 embeddings geschrieben
# 324000 embeddings geschrieben
# 324500 embeddings geschrieben
# 325000 embeddings geschrieben
# 325500 embeddings geschrieben
# 326000 embeddings geschrieben
# 326500 embeddings geschrieben
# 327000 embeddings geschrieben
# 327500 embeddings geschrieben
# 328000 embeddings geschrieben
# 328500 embeddings geschrieben
# 329000 embeddings geschrieben
# 329500 embeddings geschrieben
# 330000 embeddings geschrieben
# 330500 embeddings geschrieben
# 331000 embeddings geschrieben
# 331500 embeddings geschrieben
# 332000 embeddings geschrieben
# 332500 embeddings geschrieben
# 333000 embeddings geschrieben
# 333500 embeddings geschrieben
# 334000 embeddings geschrieben
# 334500 embeddings geschrieben
# 335000 embeddings geschrieben
# 335500 embeddings geschrieben
# 336000 embeddings geschrieben
# 336500 embeddings geschrieben
# 337000 embeddings geschrieben
# 337500 embeddings geschrieben
# 338000 embeddings geschrieben
# 338500 embeddings geschrieben
# 339000 embeddings geschrieben
# 339500 embeddings geschrieben
# 340000 embeddings geschrieben
# 340500 embeddings geschrieben
# 341000 embeddings geschrieben
# 341500 embeddings geschrieben
# 342000 embeddings geschrieben
# 342500 embeddings geschrieben
# 343000 embeddings geschrieben
# 343500 embeddings geschrieben
# 344000 embeddings geschrieben
# 344500 embeddings geschrieben
# 345000 embeddings geschrieben
# 345500 embeddings geschrieben
# 346000 embeddings geschrieben
# 346500 embeddings geschrieben
# 347000 embeddings geschrieben
# 347500 embeddings geschrieben
# 348000 embeddings geschrieben
# 348500 embeddings geschrieben
# 349000 embeddings geschrieben
# 349500 embeddings geschrieben
# 350000 embeddings geschrieben
# 350500 embeddings geschrieben
# 351000 embeddings geschrieben
# 351500 embeddings geschrieben
# 352000 embeddings geschrieben
# 352500 embeddings geschrieben
# 353000 embeddings geschrieben
# 353500 embeddings geschrieben
# 354000 embeddings geschrieben
# 354500 embeddings geschrieben
# 355000 embeddings geschrieben
# 355500 embeddings geschrieben
# 356000 embeddings geschrieben
# 356500 embeddings geschrieben
# 357000 embeddings geschrieben
# 357500 embeddings geschrieben
# 358000 embeddings geschrieben
# 358500 embeddings geschrieben
# 359000 embeddings geschrieben
# 359500 embeddings geschrieben
# 360000 embeddings geschrieben
# 360500 embeddings geschrieben
# 361000 embeddings geschrieben
# 361500 embeddings geschrieben
# 362000 embeddings geschrieben
# 362500 embeddings geschrieben
# 363000 embeddings geschrieben
# 363500 embeddings geschrieben
# 364000 embeddings geschrieben
# 364500 embeddings geschrieben
# 365000 embeddings geschrieben
# 365500 embeddings geschrieben
# 366000 embeddings geschrieben
# 366500 embeddings geschrieben
# 367000 embeddings geschrieben
# 367500 embeddings geschrieben
# 368000 embeddings geschrieben
# 368500 embeddings geschrieben
# 369000 embeddings geschrieben
# 369500 embeddings geschrieben
# 370000 embeddings geschrieben
# 370500 embeddings geschrieben
# 371000 embeddings geschrieben
# 371500 embeddings geschrieben
# 372000 embeddings geschrieben
# 372500 embeddings geschrieben
# 373000 embeddings geschrieben
# 373500 embeddings geschrieben
# 374000 embeddings geschrieben
# 374500 embeddings geschrieben
# 375000 embeddings geschrieben
# 375500 embeddings geschrieben
# 376000 embeddings geschrieben
# 376500 embeddings geschrieben
# 377000 embeddings geschrieben
# 377500 embeddings geschrieben
# 378000 embeddings geschrieben
# 378500 embeddings geschrieben
# 379000 embeddings geschrieben
# 379500 embeddings geschrieben
# 380000 embeddings geschrieben
# 380500 embeddings geschrieben
# 381000 embeddings geschrieben
# 381500 embeddings geschrieben
# 382000 embeddings geschrieben
# 382500 embeddings geschrieben
# 383000 embeddings geschrieben
# 383500 embeddings geschrieben
# 384000 embeddings geschrieben
# 384500 embeddings geschrieben
# 385000 embeddings geschrieben
# 385500 embeddings geschrieben
# 386000 embeddings geschrieben
# 386500 embeddings geschrieben
# 387000 embeddings geschrieben
# 387500 embeddings geschrieben
# 388000 embeddings geschrieben
# 388500 embeddings geschrieben
# 389000 embeddings geschrieben
# 389500 embeddings geschrieben
# 390000 embeddings geschrieben
# 390500 embeddings geschrieben
# 391000 embeddings geschrieben
# 391500 embeddings geschrieben
# 392000 embeddings geschrieben
# 392500 embeddings geschrieben
# 393000 embeddings geschrieben
# 393500 embeddings geschrieben
# 394000 embeddings geschrieben
# 394500 embeddings geschrieben
# 395000 embeddings geschrieben
# 395500 embeddings geschrieben
# 396000 embeddings geschrieben
# 396500 embeddings geschrieben
# 397000 embeddings geschrieben
# 397500 embeddings geschrieben
# 398000 embeddings geschrieben
# 398500 embeddings geschrieben
# 399000 embeddings geschrieben
# 399500 embeddings geschrieben
# 400000 embeddings geschrieben
# 400500 embeddings geschrieben
# 401000 embeddings geschrieben
# 401500 embeddings geschrieben
# 402000 embeddings geschrieben
# 402500 embeddings geschrieben
# 403000 embeddings geschrieben
# 403500 embeddings geschrieben
# 404000 embeddings geschrieben
# 404500 embeddings geschrieben
# 405000 embeddings geschrieben
# 405500 embeddings geschrieben
# 406000 embeddings geschrieben
# 406500 embeddings geschrieben
# 407000 embeddings geschrieben
# 407500 embeddings geschrieben
# 408000 embeddings geschrieben
# 408500 embeddings geschrieben
# 409000 embeddings geschrieben
# 409500 embeddings geschrieben
# 410000 embeddings geschrieben
# 410500 embeddings geschrieben
# 411000 embeddings geschrieben
# 411500 embeddings geschrieben
# 412000 embeddings geschrieben
# 412500 embeddings geschrieben
# 413000 embeddings geschrieben
# 413500 embeddings geschrieben
# 414000 embeddings geschrieben
# 414500 embeddings geschrieben
# 415000 embeddings geschrieben
# 415500 embeddings geschrieben
# 416000 embeddings geschrieben
# 416500 embeddings geschrieben
# 417000 embeddings geschrieben
# 417500 embeddings geschrieben
# 418000 embeddings geschrieben
# 418500 embeddings geschrieben
# 419000 embeddings geschrieben
# 419500 embeddings geschrieben
# 420000 embeddings geschrieben
# 420500 embeddings geschrieben
# 421000 embeddings geschrieben
# 421500 embeddings geschrieben
# 422000 embeddings geschrieben
# 422500 embeddings geschrieben
# 423000 embeddings geschrieben
# 423500 embeddings geschrieben
# 424000 embeddings geschrieben
# 424500 embeddings geschrieben
# 425000 embeddings geschrieben
# 425500 embeddings geschrieben
# 426000 embeddings geschrieben
# 426500 embeddings geschrieben
# 427000 embeddings geschrieben
# 427500 embeddings geschrieben
# 428000 embeddings geschrieben
# 428500 embeddings geschrieben
# 429000 embeddings geschrieben
# 429500 embeddings geschrieben
# 430000 embeddings geschrieben
# 430500 embeddings geschrieben
# 431000 embeddings geschrieben
# 431500 embeddings geschrieben
# 432000 embeddings geschrieben
# 432500 embeddings geschrieben
# 433000 embeddings geschrieben
# 433500 embeddings geschrieben
# 434000 embeddings geschrieben
# 434500 embeddings geschrieben
# 435000 embeddings geschrieben
# 435500 embeddings geschrieben
# 436000 embeddings geschrieben
# 436500 embeddings geschrieben
# 437000 embeddings geschrieben
# 437500 embeddings geschrieben
# 438000 embeddings geschrieben
# 438500 embeddings geschrieben
# 439000 embeddings geschrieben
# 439500 embeddings geschrieben
# 440000 embeddings geschrieben
# 440500 embeddings geschrieben
# 441000 embeddings geschrieben
# 441500 embeddings geschrieben
# 442000 embeddings geschrieben
# 442500 embeddings geschrieben
# 443000 embeddings geschrieben
# 443500 embeddings geschrieben
# 444000 embeddings geschrieben
# 444500 embeddings geschrieben
# 445000 embeddings geschrieben
# 445500 embeddings geschrieben
# 446000 embeddings geschrieben
# 446500 embeddings geschrieben
# 447000 embeddings geschrieben
# 447500 embeddings geschrieben
# 448000 embeddings geschrieben
# 448500 embeddings geschrieben
# 449000 embeddings geschrieben
# 449500 embeddings geschrieben
# 450000 embeddings geschrieben
# 450500 embeddings geschrieben
# 451000 embeddings geschrieben
# 451500 embeddings geschrieben
# 452000 embeddings geschrieben
# 452500 embeddings geschrieben
# 453000 embeddings geschrieben
# 453500 embeddings geschrieben
# 454000 embeddings geschrieben
# 454500 embeddings geschrieben
# 455000 embeddings geschrieben
# 455500 embeddings geschrieben
# 456000 embeddings geschrieben
# 456500 embeddings geschrieben
# 457000 embeddings geschrieben
# 457500 embeddings geschrieben
# 458000 embeddings geschrieben
# 458500 embeddings geschrieben
# 459000 embeddings geschrieben
# 459500 embeddings geschrieben
# 460000 embeddings geschrieben
# 460500 embeddings geschrieben
# 461000 embeddings geschrieben
# 461500 embeddings geschrieben
# 462000 embeddings geschrieben
# 462500 embeddings geschrieben
# 463000 embeddings geschrieben
# 463500 embeddings geschrieben
# 464000 embeddings geschrieben
# 464500 embeddings geschrieben
# 465000 embeddings geschrieben
# 465500 embeddings geschrieben
# 466000 embeddings geschrieben
# 466500 embeddings geschrieben
# 467000 embeddings geschrieben
# 467500 embeddings geschrieben
# 468000 embeddings geschrieben
# 468500 embeddings geschrieben
# 469000 embeddings geschrieben
# 469500 embeddings geschrieben
# 470000 embeddings geschrieben
# 470500 embeddings geschrieben
# 471000 embeddings geschrieben
# 471500 embeddings geschrieben
# 472000 embeddings geschrieben
# 472500 embeddings geschrieben
# 473000 embeddings geschrieben
# 473500 embeddings geschrieben
# 474000 embeddings geschrieben
# 474500 embeddings geschrieben
# 475000 embeddings geschrieben
# 475500 embeddings geschrieben
# 476000 embeddings geschrieben
# 476500 embeddings geschrieben
# 477000 embeddings geschrieben
# 477500 embeddings geschrieben
# 478000 embeddings geschrieben
# 478500 embeddings geschrieben
# 479000 embeddings geschrieben
# 479500 embeddings geschrieben
# 480000 embeddings geschrieben
# 480500 embeddings geschrieben
# 481000 embeddings geschrieben
# 481500 embeddings geschrieben
# 482000 embeddings geschrieben
# 482500 embeddings geschrieben
# 483000 embeddings geschrieben
# 483500 embeddings geschrieben
# 484000 embeddings geschrieben
# 484500 embeddings geschrieben
# 485000 embeddings geschrieben
# 485500 embeddings geschrieben
# 486000 embeddings geschrieben
# 486500 embeddings geschrieben
# 487000 embeddings geschrieben
# 487500 embeddings geschrieben
# 488000 embeddings geschrieben
# 488500 embeddings geschrieben
# 489000 embeddings geschrieben
# 489500 embeddings geschrieben
# 490000 embeddings geschrieben
# 490500 embeddings geschrieben
# 491000 embeddings geschrieben
# 491500 embeddings geschrieben
# 492000 embeddings geschrieben
# 492500 embeddings geschrieben
# 493000 embeddings geschrieben
# 493500 embeddings geschrieben
# 494000 embeddings geschrieben
# 494500 embeddings geschrieben
# 495000 embeddings geschrieben
# 495500 embeddings geschrieben
# 496000 embeddings geschrieben
# 496500 embeddings geschrieben
# 497000 embeddings geschrieben
# 497500 embeddings geschrieben
# 498000 embeddings geschrieben
# 498500 embeddings geschrieben
# 499000 embeddings geschrieben
# 499500 embeddings geschrieben
# 500000 embeddings geschrieben
# 500500 embeddings geschrieben
# 501000 embeddings geschrieben
# 501500 embeddings geschrieben
# 502000 embeddings geschrieben
# 502500 embeddings geschrieben
# 503000 embeddings geschrieben
# 503500 embeddings geschrieben
# 504000 embeddings geschrieben
# 504500 embeddings geschrieben
# 505000 embeddings geschrieben
# 505500 embeddings geschrieben
# 506000 embeddings geschrieben
# 506500 embeddings geschrieben
# 507000 embeddings geschrieben
# 507500 embeddings geschrieben
# 508000 embeddings geschrieben
# 508500 embeddings geschrieben
# 509000 embeddings geschrieben
# 509500 embeddings geschrieben
# 510000 embeddings geschrieben
# 510500 embeddings geschrieben
# 511000 embeddings geschrieben
# 511500 embeddings geschrieben
# 512000 embeddings geschrieben
# 512500 embeddings geschrieben
# 513000 embeddings geschrieben
# 513500 embeddings geschrieben
# 514000 embeddings geschrieben
# 514500 embeddings geschrieben
# 515000 embeddings geschrieben
# 515500 embeddings geschrieben
# 516000 embeddings geschrieben
# 516500 embeddings geschrieben
# 517000 embeddings geschrieben
# 517500 embeddings geschrieben
# 518000 embeddings geschrieben
# 518500 embeddings geschrieben
# 519000 embeddings geschrieben
# 519500 embeddings geschrieben
# 520000 embeddings geschrieben
# 520500 embeddings geschrieben
# 521000 embeddings geschrieben
# 521500 embeddings geschrieben
# 522000 embeddings geschrieben
# 522500 embeddings geschrieben
# 523000 embeddings geschrieben
# 523500 embeddings geschrieben
# 524000 embeddings geschrieben
# 524500 embeddings geschrieben
# 525000 embeddings geschrieben
# 525500 embeddings geschrieben
# 526000 embeddings geschrieben
# 526500 embeddings geschrieben
# 527000 embeddings geschrieben
# 527500 embeddings geschrieben
# 528000 embeddings geschrieben
# 528500 embeddings geschrieben
# 529000 embeddings geschrieben
# 529500 embeddings geschrieben
# 530000 embeddings geschrieben
# 530500 embeddings geschrieben
# 531000 embeddings geschrieben
# 531500 embeddings geschrieben
# 532000 embeddings geschrieben
# 532500 embeddings geschrieben
# 533000 embeddings geschrieben
# 533500 embeddings geschrieben
# 534000 embeddings geschrieben
# 534500 embeddings geschrieben
# 535000 embeddings geschrieben
# 535500 embeddings geschrieben
# 536000 embeddings geschrieben
# 536500 embeddings geschrieben
# 537000 embeddings geschrieben
# 537500 embeddings geschrieben
# 538000 embeddings geschrieben
# 538500 embeddings geschrieben
# 539000 embeddings geschrieben
# 539500 embeddings geschrieben
# 540000 embeddings geschrieben
# 540500 embeddings geschrieben
# 541000 embeddings geschrieben
# 541500 embeddings geschrieben
# 542000 embeddings geschrieben
# 542500 embeddings geschrieben
# 543000 embeddings geschrieben
# 543500 embeddings geschrieben
# 544000 embeddings geschrieben
# 544500 embeddings geschrieben
# 545000 embeddings geschrieben
# 545500 embeddings geschrieben
# 546000 embeddings geschrieben
# 546500 embeddings geschrieben
# 547000 embeddings geschrieben
# 547500 embeddings geschrieben
# 548000 embeddings geschrieben
# 548500 embeddings geschrieben
# 549000 embeddings geschrieben
# 549500 embeddings geschrieben
# 550000 embeddings geschrieben
# 550500 embeddings geschrieben
# 551000 embeddings geschrieben
# 551500 embeddings geschrieben
# 552000 embeddings geschrieben
# 552500 embeddings geschrieben
# 553000 embeddings geschrieben
# 553500 embeddings geschrieben
# 554000 embeddings geschrieben
# 554500 embeddings geschrieben
# 555000 embeddings geschrieben
# 555500 embeddings geschrieben
# 556000 embeddings geschrieben
# 556500 embeddings geschrieben
# 557000 embeddings geschrieben
# 557500 embeddings geschrieben
# 558000 embeddings geschrieben
# 558500 embeddings geschrieben
# 559000 embeddings geschrieben
# 559500 embeddings geschrieben
# 560000 embeddings geschrieben
# 560500 embeddings geschrieben
# 561000 embeddings geschrieben
# 561500 embeddings geschrieben
# 562000 embeddings geschrieben
# 562500 embeddings geschrieben
# 563000 embeddings geschrieben
# 563500 embeddings geschrieben
# 564000 embeddings geschrieben
# 564500 embeddings geschrieben
# 565000 embeddings geschrieben
# 565500 embeddings geschrieben
# 566000 embeddings geschrieben
# 566500 embeddings geschrieben
# 567000 embeddings geschrieben
# 567500 embeddings geschrieben
# 568000 embeddings geschrieben
# 568500 embeddings geschrieben
# 569000 embeddings geschrieben
# 569500 embeddings geschrieben
# 570000 embeddings geschrieben
# 570500 embeddings geschrieben
# 571000 embeddings geschrieben
# 571500 embeddings geschrieben
# 572000 embeddings geschrieben
# 572500 embeddings geschrieben
# 573000 embeddings geschrieben
# 573500 embeddings geschrieben
# 574000 embeddings geschrieben
# 574500 embeddings geschrieben
# 575000 embeddings geschrieben
# 575500 embeddings geschrieben
# 576000 embeddings geschrieben
# 576500 embeddings geschrieben
# 577000 embeddings geschrieben
# 577500 embeddings geschrieben
# 578000 embeddings geschrieben
# 578500 embeddings geschrieben
# 579000 embeddings geschrieben
# 579500 embeddings geschrieben
# 580000 embeddings geschrieben
# 580500 embeddings geschrieben
# 581000 embeddings geschrieben
# 581500 embeddings geschrieben
# 582000 embeddings geschrieben
# 582500 embeddings geschrieben
# 583000 embeddings geschrieben
# 583500 embeddings geschrieben
# 584000 embeddings geschrieben
# 584500 embeddings geschrieben
# 585000 embeddings geschrieben
# 585500 embeddings geschrieben
# 586000 embeddings geschrieben
# 586500 embeddings geschrieben
# 587000 embeddings geschrieben
# 587500 embeddings geschrieben
# 588000 embeddings geschrieben
# 588500 embeddings geschrieben
# 589000 embeddings geschrieben
# 589500 embeddings geschrieben
# 590000 embeddings geschrieben
# 590500 embeddings geschrieben
# 591000 embeddings geschrieben
# 591500 embeddings geschrieben
# 592000 embeddings geschrieben
# 592500 embeddings geschrieben
# 593000 embeddings geschrieben
# 593500 embeddings geschrieben
# 594000 embeddings geschrieben
# 594500 embeddings geschrieben
# 595000 embeddings geschrieben
# 595500 embeddings geschrieben
# 596000 embeddings geschrieben
# 596500 embeddings geschrieben
# 597000 embeddings geschrieben
# 597500 embeddings geschrieben
# 598000 embeddings geschrieben
# 598500 embeddings geschrieben
# 599000 embeddings geschrieben
# 599500 embeddings geschrieben
# 600000 embeddings geschrieben
# 600500 embeddings geschrieben
# 601000 embeddings geschrieben
# 601500 embeddings geschrieben
# 602000 embeddings geschrieben
# 602500 embeddings geschrieben
# 603000 embeddings geschrieben
# 603500 embeddings geschrieben
# 604000 embeddings geschrieben
# 604500 embeddings geschrieben
# 605000 embeddings geschrieben
# 605500 embeddings geschrieben
# 606000 embeddings geschrieben
# 606500 embeddings geschrieben
# 607000 embeddings geschrieben
# 607500 embeddings geschrieben
# 608000 embeddings geschrieben
# 608500 embeddings geschrieben
# 609000 embeddings geschrieben
# 609500 embeddings geschrieben
# 610000 embeddings geschrieben
# 610500 embeddings geschrieben
# 611000 embeddings geschrieben
# 611500 embeddings geschrieben
# 612000 embeddings geschrieben
# 612500 embeddings geschrieben
# 613000 embeddings geschrieben
# 613500 embeddings geschrieben
# 614000 embeddings geschrieben
# 614500 embeddings geschrieben
# 615000 embeddings geschrieben
# 615500 embeddings geschrieben
# 616000 embeddings geschrieben
# 616500 embeddings geschrieben
# 617000 embeddings geschrieben
# 617500 embeddings geschrieben
# 618000 embeddings geschrieben
# 618500 embeddings geschrieben
# 619000 embeddings geschrieben
# 619500 embeddings geschrieben
# 620000 embeddings geschrieben
# 620500 embeddings geschrieben
# 621000 embeddings geschrieben
# 621500 embeddings geschrieben
# 622000 embeddings geschrieben
# 622500 embeddings geschrieben
# 623000 embeddings geschrieben
# 623500 embeddings geschrieben
# 624000 embeddings geschrieben
# 624500 embeddings geschrieben
# 625000 embeddings geschrieben
# 625500 embeddings geschrieben
# 626000 embeddings geschrieben
# 626500 embeddings geschrieben
# 627000 embeddings geschrieben
# 627500 embeddings geschrieben
# 628000 embeddings geschrieben
# 628500 embeddings geschrieben
# 629000 embeddings geschrieben
# 629500 embeddings geschrieben
# 630000 embeddings geschrieben
# 630500 embeddings geschrieben
# 631000 embeddings geschrieben
# 631500 embeddings geschrieben
# 632000 embeddings geschrieben
# 632500 embeddings geschrieben
# 633000 embeddings geschrieben
# 633500 embeddings geschrieben
# 634000 embeddings geschrieben
# 634500 embeddings geschrieben
# 635000 embeddings geschrieben
# 635500 embeddings geschrieben
# 636000 embeddings geschrieben
# 636500 embeddings geschrieben
# 637000 embeddings geschrieben
# 637500 embeddings geschrieben
# 638000 embeddings geschrieben
# 638500 embeddings geschrieben
# 639000 embeddings geschrieben
# 639500 embeddings geschrieben
# 640000 embeddings geschrieben
# 640500 embeddings geschrieben
# 641000 embeddings geschrieben
# 641500 embeddings geschrieben
# 642000 embeddings geschrieben
# 642500 embeddings geschrieben
# 643000 embeddings geschrieben
# 643500 embeddings geschrieben
# 644000 embeddings geschrieben
# 644500 embeddings geschrieben
# 645000 embeddings geschrieben
# 645500 embeddings geschrieben
# 646000 embeddings geschrieben
# 646500 embeddings geschrieben
# 647000 embeddings geschrieben
# 647500 embeddings geschrieben
# 648000 embeddings geschrieben
# 648500 embeddings geschrieben
# 649000 embeddings geschrieben
# 649500 embeddings geschrieben
# 650000 embeddings geschrieben
# 650500 embeddings geschrieben
# 651000 embeddings geschrieben
# 651500 embeddings geschrieben
# 652000 embeddings geschrieben
# 652500 embeddings geschrieben
# 653000 embeddings geschrieben
# 653500 embeddings geschrieben
# 654000 embeddings geschrieben
# 654500 embeddings geschrieben
# 655000 embeddings geschrieben
# 655500 embeddings geschrieben
# 656000 embeddings geschrieben
# 656500 embeddings geschrieben
# 657000 embeddings geschrieben
# 657500 embeddings geschrieben
# 658000 embeddings geschrieben
# 658500 embeddings geschrieben
# 659000 embeddings geschrieben
# 659500 embeddings geschrieben
# 660000 embeddings geschrieben
# 660500 embeddings geschrieben
# 661000 embeddings geschrieben
# 661500 embeddings geschrieben
# 662000 embeddings geschrieben
# 662500 embeddings geschrieben
# 663000 embeddings geschrieben
# 663500 embeddings geschrieben
# 664000 embeddings geschrieben
# 664500 embeddings geschrieben
# 665000 embeddings geschrieben
# 665500 embeddings geschrieben
# 666000 embeddings geschrieben
# 666500 embeddings geschrieben
# 667000 embeddings geschrieben
# 667500 embeddings geschrieben
# 668000 embeddings geschrieben
# 668500 embeddings geschrieben
# 669000 embeddings geschrieben
# 669500 embeddings geschrieben
# 670000 embeddings geschrieben
# 670500 embeddings geschrieben
# 671000 embeddings geschrieben
# 671500 embeddings geschrieben
# 672000 embeddings geschrieben
# 672500 embeddings geschrieben
# 673000 embeddings geschrieben
# 673500 embeddings geschrieben
# 674000 embeddings geschrieben
# 674500 embeddings geschrieben
# 675000 embeddings geschrieben
# 675500 embeddings geschrieben
# 676000 embeddings geschrieben
# 676500 embeddings geschrieben
# 677000 embeddings geschrieben
# 677500 embeddings geschrieben
# 678000 embeddings geschrieben
# 678500 embeddings geschrieben
# 679000 embeddings geschrieben
# 679500 embeddings geschrieben
# 680000 embeddings geschrieben
# 680500 embeddings geschrieben
# 681000 embeddings geschrieben
# 681500 embeddings geschrieben
# 682000 embeddings geschrieben
# 682500 embeddings geschrieben
# 683000 embeddings geschrieben
# 683500 embeddings geschrieben
# 684000 embeddings geschrieben
# 684500 embeddings geschrieben
# 685000 embeddings geschrieben
# 685500 embeddings geschrieben
# 686000 embeddings geschrieben
# 686500 embeddings geschrieben
# 687000 embeddings geschrieben
# 687500 embeddings geschrieben
# 688000 embeddings geschrieben
# 688500 embeddings geschrieben
# 689000 embeddings geschrieben
# 689500 embeddings geschrieben
# 690000 embeddings geschrieben
# 690500 embeddings geschrieben
# 691000 embeddings geschrieben
# 691500 embeddings geschrieben
# 692000 embeddings geschrieben
# 692500 embeddings geschrieben
# 693000 embeddings geschrieben
# 693500 embeddings geschrieben
# 694000 embeddings geschrieben
# 694500 embeddings geschrieben
# 695000 embeddings geschrieben
# 695500 embeddings geschrieben
# 696000 embeddings geschrieben
# 696500 embeddings geschrieben
# 697000 embeddings geschrieben
# 697500 embeddings geschrieben
# 698000 embeddings geschrieben
# 698500 embeddings geschrieben
# 699000 embeddings geschrieben
# 699500 embeddings geschrieben
# 700000 embeddings geschrieben
# 700500 embeddings geschrieben
# 701000 embeddings geschrieben
# 701500 embeddings geschrieben
# 702000 embeddings geschrieben
# 702500 embeddings geschrieben
# 703000 embeddings geschrieben
# 703500 embeddings geschrieben
# 704000 embeddings geschrieben
# 704500 embeddings geschrieben
# 705000 embeddings geschrieben
# 705500 embeddings geschrieben
# 706000 embeddings geschrieben
# 706500 embeddings geschrieben
# 707000 embeddings geschrieben
# 707500 embeddings geschrieben
# 708000 embeddings geschrieben
# 708500 embeddings geschrieben
# 709000 embeddings geschrieben
# 709500 embeddings geschrieben
# 710000 embeddings geschrieben
# 710500 embeddings geschrieben
# 711000 embeddings geschrieben
# 711500 embeddings geschrieben
# 712000 embeddings geschrieben
# 712500 embeddings geschrieben
# 713000 embeddings geschrieben
# 713500 embeddings geschrieben
# 714000 embeddings geschrieben
# 714500 embeddings geschrieben
# 715000 embeddings geschrieben
# 715500 embeddings geschrieben
# 716000 embeddings geschrieben
# 716500 embeddings geschrieben
# 717000 embeddings geschrieben
# 717500 embeddings geschrieben
# 718000 embeddings geschrieben
# 718500 embeddings geschrieben
# 719000 embeddings geschrieben
# 719500 embeddings geschrieben
# 720000 embeddings geschrieben
# 720500 embeddings geschrieben
# 721000 embeddings geschrieben
# 721500 embeddings geschrieben
# 722000 embeddings geschrieben
# 722500 embeddings geschrieben
# 723000 embeddings geschrieben
# 723500 embeddings geschrieben
# 724000 embeddings geschrieben
# 724500 embeddings geschrieben
# 725000 embeddings geschrieben
# 725500 embeddings geschrieben
# 726000 embeddings geschrieben
# 726500 embeddings geschrieben
# 727000 embeddings geschrieben
# 727500 embeddings geschrieben
# 728000 embeddings geschrieben
# 728500 embeddings geschrieben
# 729000 embeddings geschrieben
# 729500 embeddings geschrieben
# 730000 embeddings geschrieben
# 730500 embeddings geschrieben
# 731000 embeddings geschrieben
# 731500 embeddings geschrieben
# 732000 embeddings geschrieben
# 732500 embeddings geschrieben
# 733000 embeddings geschrieben
# 733500 embeddings geschrieben
# 734000 embeddings geschrieben
# 734500 embeddings geschrieben
# 735000 embeddings geschrieben
# 735500 embeddings geschrieben
# 736000 embeddings geschrieben
# 736500 embeddings geschrieben
# 737000 embeddings geschrieben
# 737500 embeddings geschrieben
# 738000 embeddings geschrieben
# 738500 embeddings geschrieben
# 739000 embeddings geschrieben
# 739500 embeddings geschrieben
# 740000 embeddings geschrieben
# 740500 embeddings geschrieben
# 741000 embeddings geschrieben
# 741500 embeddings geschrieben
# 742000 embeddings geschrieben
# 742500 embeddings geschrieben
# 743000 embeddings geschrieben
# 743500 embeddings geschrieben
# 744000 embeddings geschrieben
# 744500 embeddings geschrieben
# 745000 embeddings geschrieben
# 745500 embeddings geschrieben
# 746000 embeddings geschrieben
# 746500 embeddings geschrieben
# 747000 embeddings geschrieben
# 747500 embeddings geschrieben
# 748000 embeddings geschrieben
# 748500 embeddings geschrieben
# 749000 embeddings geschrieben
# 749500 embeddings geschrieben
# 750000 embeddings geschrieben
# 750500 embeddings geschrieben
# 751000 embeddings geschrieben
# 751500 embeddings geschrieben
# 752000 embeddings geschrieben
# 752500 embeddings geschrieben
# 753000 embeddings geschrieben
# 753500 embeddings geschrieben
# 754000 embeddings geschrieben
# 754500 embeddings geschrieben
# 755000 embeddings geschrieben
# 755500 embeddings geschrieben
# 756000 embeddings geschrieben
# 756500 embeddings geschrieben
# 757000 embeddings geschrieben
# 757500 embeddings geschrieben
# 758000 embeddings geschrieben
# 758500 embeddings geschrieben
# 759000 embeddings geschrieben
# 759500 embeddings geschrieben
# 760000 embeddings geschrieben
# 760500 embeddings geschrieben
# 761000 embeddings geschrieben
# 761500 embeddings geschrieben
# 762000 embeddings geschrieben
# 762500 embeddings geschrieben
# 763000 embeddings geschrieben
# 763500 embeddings geschrieben
# 764000 embeddings geschrieben
# 764500 embeddings geschrieben
# 765000 embeddings geschrieben
# 765500 embeddings geschrieben
# 766000 embeddings geschrieben
# 766500 embeddings geschrieben
# 767000 embeddings geschrieben
# 767500 embeddings geschrieben
# 768000 embeddings geschrieben
# 768500 embeddings geschrieben
# 769000 embeddings geschrieben
# 769500 embeddings geschrieben
# 770000 embeddings geschrieben
# 770500 embeddings geschrieben
# 771000 embeddings geschrieben
# 771500 embeddings geschrieben
# 772000 embeddings geschrieben
# 772500 embeddings geschrieben
# 773000 embeddings geschrieben
# 773500 embeddings geschrieben
# 774000 embeddings geschrieben
# 774500 embeddings geschrieben
# 775000 embeddings geschrieben
# 775500 embeddings geschrieben
# 776000 embeddings geschrieben
# 776500 embeddings geschrieben
# 777000 embeddings geschrieben
# 777500 embeddings geschrieben
# 778000 embeddings geschrieben
# 778500 embeddings geschrieben
# 779000 embeddings geschrieben
# 779500 embeddings geschrieben
# 780000 embeddings geschrieben
# 780500 embeddings geschrieben
# 781000 embeddings geschrieben
# 781500 embeddings geschrieben
# 782000 embeddings geschrieben
# 782500 embeddings geschrieben
# 783000 embeddings geschrieben
# 783500 embeddings geschrieben
# 784000 embeddings geschrieben
# 784500 embeddings geschrieben
# 785000 embeddings geschrieben
# 785500 embeddings geschrieben
# 786000 embeddings geschrieben
# 786500 embeddings geschrieben
# 787000 embeddings geschrieben
# 787500 embeddings geschrieben
# 788000 embeddings geschrieben
# 788500 embeddings geschrieben
# 789000 embeddings geschrieben
# 789500 embeddings geschrieben
# 790000 embeddings geschrieben
# 790500 embeddings geschrieben
# 791000 embeddings geschrieben
# 791500 embeddings geschrieben
# 792000 embeddings geschrieben
# 792500 embeddings geschrieben
# 793000 embeddings geschrieben
# 793500 embeddings geschrieben
# 794000 embeddings geschrieben
# 794500 embeddings geschrieben
# 795000 embeddings geschrieben
# 795500 embeddings geschrieben
# 796000 embeddings geschrieben
# 796500 embeddings geschrieben
# 797000 embeddings geschrieben
# 797500 embeddings geschrieben
# 798000 embeddings geschrieben
# 798500 embeddings geschrieben
# 799000 embeddings geschrieben
# 799500 embeddings geschrieben
# 800000 embeddings geschrieben
# 800500 embeddings geschrieben
# 801000 embeddings geschrieben
# 801500 embeddings geschrieben
# 802000 embeddings geschrieben
# 802500 embeddings geschrieben
# 803000 embeddings geschrieben
# 803500 embeddings geschrieben
# ...
# 16115000 embeddings geschrieben
# 16115500 embeddings geschrieben
# 16116000 embeddings geschrieben
# 16116500 embeddings geschrieben
# 16117000 embeddings geschrieben
# 16117500 embeddings geschrieben
# 16118000 embeddings geschrieben
# 16118500 embeddings geschrieben
# 16119000 embeddings geschrieben
# 16119500 embeddings geschrieben
# 16120000 embeddings geschrieben
# 16120500 embeddings geschrieben
# 16121000 embeddings geschrieben
# 16121500 embeddings geschrieben
# 16122000 embeddings geschrieben
# 16122500 embeddings geschrieben
# 16123000 embeddings geschrieben
# 16123500 embeddings geschrieben
# 16124000 embeddings geschrieben
# 16124500 embeddings geschrieben
# 16125000 embeddings geschrieben
# 16125500 embeddings geschrieben
# 16126000 embeddings geschrieben
# 16126500 embeddings geschrieben
# 16127000 embeddings geschrieben
# 16127500 embeddings geschrieben
# 16128000 embeddings geschrieben
# 16128500 embeddings geschrieben
# 16129000 embeddings geschrieben
# 16129500 embeddings geschrieben
# 16130000 embeddings geschrieben
# 16130500 embeddings geschrieben
# 16131000 embeddings geschrieben
# 16131500 embeddings geschrieben
# 16132000 embeddings geschrieben
# 16132500 embeddings geschrieben
# 16133000 embeddings geschrieben
# 16133500 embeddings geschrieben
# 16134000 embeddings geschrieben
# 16134500 embeddings geschrieben
# 16135000 embeddings geschrieben
# 16135500 embeddings geschrieben
# 16136000 embeddings geschrieben
# 16136500 embeddings geschrieben
# 16137000 embeddings geschrieben
# 16137500 embeddings geschrieben
# 16138000 embeddings geschrieben
# 16138500 embeddings geschrieben
# 16139000 embeddings geschrieben
# 16139500 embeddings geschrieben
# 16140000 embeddings geschrieben
# 16140500 embeddings geschrieben
# 16141000 embeddings geschrieben
# 16141500 embeddings geschrieben
# 16142000 embeddings geschrieben
# 16142500 embeddings geschrieben
# 16143000 embeddings geschrieben
# 16143500 embeddings geschrieben
# 16144000 embeddings geschrieben
# 16144500 embeddings geschrieben
# 16145000 embeddings geschrieben
# 16145500 embeddings geschrieben
# 16146000 embeddings geschrieben
# 16146500 embeddings geschrieben
# 16147000 embeddings geschrieben
# 16147500 embeddings geschrieben
# 16148000 embeddings geschrieben
# 16148500 embeddings geschrieben
# 16149000 embeddings geschrieben
# 16149500 embeddings geschrieben
# 16150000 embeddings geschrieben
# 16150500 embeddings geschrieben
# 16151000 embeddings geschrieben
# 16151500 embeddings geschrieben
# 16152000 embeddings geschrieben
# 16152500 embeddings geschrieben
# 16153000 embeddings geschrieben
# 16153500 embeddings geschrieben
# 16154000 embeddings geschrieben
# 16154500 embeddings geschrieben
# 16155000 embeddings geschrieben
# 16155500 embeddings geschrieben
# 16156000 embeddings geschrieben
# 16156500 embeddings geschrieben
# 16157000 embeddings geschrieben
# 16157500 embeddings geschrieben
# 16158000 embeddings geschrieben
# 16158500 embeddings geschrieben
# 16159000 embeddings geschrieben
# 16159500 embeddings geschrieben
# 16160000 embeddings geschrieben
# 16160500 embeddings geschrieben
# 16161000 embeddings geschrieben
# 16161500 embeddings geschrieben
# 16162000 embeddings geschrieben
# 16162500 embeddings geschrieben
# 16163000 embeddings geschrieben
# 16163500 embeddings geschrieben
# 16164000 embeddings geschrieben
# 16164500 embeddings geschrieben
# 16165000 embeddings geschrieben
# 16165500 embeddings geschrieben
# 16166000 embeddings geschrieben
# 16166500 embeddings geschrieben
# 16167000 embeddings geschrieben
# 16167500 embeddings geschrieben
# 16168000 embeddings geschrieben
# 16168500 embeddings geschrieben
# 16169000 embeddings geschrieben
# 16169500 embeddings geschrieben
# 16170000 embeddings geschrieben
# 16170500 embeddings geschrieben
# 16171000 embeddings geschrieben
# 16171500 embeddings geschrieben
# 16172000 embeddings geschrieben
# 16172500 embeddings geschrieben
# 16173000 embeddings geschrieben
# 16173500 embeddings geschrieben
# 16174000 embeddings geschrieben
# 16174500 embeddings geschrieben
# 16175000 embeddings geschrieben
# 16175500 embeddings geschrieben
# 16176000 embeddings geschrieben
# 16176500 embeddings geschrieben
# 16177000 embeddings geschrieben
# 16177500 embeddings geschrieben
# 16178000 embeddings geschrieben
# 16178500 embeddings geschrieben
# 16179000 embeddings geschrieben
# 16179500 embeddings geschrieben
# 16180000 embeddings geschrieben
# 16180500 embeddings geschrieben
# 16181000 embeddings geschrieben
# 16181500 embeddings geschrieben
# 16182000 embeddings geschrieben
# 16182500 embeddings geschrieben
# 16183000 embeddings geschrieben
# 16183500 embeddings geschrieben
# 16184000 embeddings geschrieben
# 16184500 embeddings geschrieben
# 16185000 embeddings geschrieben
# 16185500 embeddings geschrieben
# 16186000 embeddings geschrieben
# 16186500 embeddings geschrieben
# 16187000 embeddings geschrieben
# 16187500 embeddings geschrieben
# 16188000 embeddings geschrieben
# 16188500 embeddings geschrieben
# 16189000 embeddings geschrieben
# 16189500 embeddings geschrieben
# 16190000 embeddings geschrieben
# 16190500 embeddings geschrieben
# 16191000 embeddings geschrieben
# 16191500 embeddings geschrieben
# 16192000 embeddings geschrieben
# 16192500 embeddings geschrieben
# 16193000 embeddings geschrieben
# 16193500 embeddings geschrieben
# 16194000 embeddings geschrieben
# 16194500 embeddings geschrieben
# 16195000 embeddings geschrieben
# 16195500 embeddings geschrieben
# 16196000 embeddings geschrieben
# 16196500 embeddings geschrieben
# 16197000 embeddings geschrieben
# 16197500 embeddings geschrieben
# 16198000 embeddings geschrieben
# 16198500 embeddings geschrieben
# 16199000 embeddings geschrieben
# 16199500 embeddings geschrieben
# 16200000 embeddings geschrieben
# 16200500 embeddings geschrieben
# 16201000 embeddings geschrieben
# 16201500 embeddings geschrieben
# 16202000 embeddings geschrieben
# 16202500 embeddings geschrieben
# 16203000 embeddings geschrieben
# 16203500 embeddings geschrieben
# 16204000 embeddings geschrieben
# 16204500 embeddings geschrieben
# 16205000 embeddings geschrieben
# 16205500 embeddings geschrieben
# 16206000 embeddings geschrieben
# 16206500 embeddings geschrieben
# 16207000 embeddings geschrieben
# 16207500 embeddings geschrieben
# 16208000 embeddings geschrieben
# 16208500 embeddings geschrieben
# 16209000 embeddings geschrieben
# 16209500 embeddings geschrieben
# 16210000 embeddings geschrieben
# 16210500 embeddings geschrieben
# 16211000 embeddings geschrieben
# 16211500 embeddings geschrieben
# 16212000 embeddings geschrieben
# 16212500 embeddings geschrieben
# 16213000 embeddings geschrieben
# 16213500 embeddings geschrieben
# 16214000 embeddings geschrieben
# 16214500 embeddings geschrieben
# 16215000 embeddings geschrieben
# 16215500 embeddings geschrieben
# 16216000 embeddings geschrieben
# 16216500 embeddings geschrieben
# 16217000 embeddings geschrieben
# 16217500 embeddings geschrieben
# 16218000 embeddings geschrieben
# 16218500 embeddings geschrieben
# 16219000 embeddings geschrieben
# 16219500 embeddings geschrieben
# 16220000 embeddings geschrieben
# 16220500 embeddings geschrieben
# 16221000 embeddings geschrieben
# 16221500 embeddings geschrieben
# 16222000 embeddings geschrieben
# 16222500 embeddings geschrieben
# 16223000 embeddings geschrieben
# 16223500 embeddings geschrieben
# 16224000 embeddings geschrieben
# 16224500 embeddings geschrieben
# 16225000 embeddings geschrieben
# 16225500 embeddings geschrieben
# 16226000 embeddings geschrieben
# 16226500 embeddings geschrieben
# 16227000 embeddings geschrieben
# 16227500 embeddings geschrieben
# 16228000 embeddings geschrieben
# 16228500 embeddings geschrieben
# 16229000 embeddings geschrieben
# 16229500 embeddings geschrieben
# 16230000 embeddings geschrieben
# 16230500 embeddings geschrieben
# 16231000 embeddings geschrieben
# 16231500 embeddings geschrieben
# 16232000 embeddings geschrieben
# 16232500 embeddings geschrieben
# 16233000 embeddings geschrieben
# 16233500 embeddings geschrieben
# 16234000 embeddings geschrieben
# 16234500 embeddings geschrieben
# 16235000 embeddings geschrieben
# 16235500 embeddings geschrieben
# 16236000 embeddings geschrieben
# 16236500 embeddings geschrieben
# 16237000 embeddings geschrieben
# 16237500 embeddings geschrieben
# 16238000 embeddings geschrieben
# 16238500 embeddings geschrieben
# 16239000 embeddings geschrieben
# 16239500 embeddings geschrieben
# 16240000 embeddings geschrieben
# 16240500 embeddings geschrieben
# 16241000 embeddings geschrieben
# 16241500 embeddings geschrieben
# 16242000 embeddings geschrieben
# 16242500 embeddings geschrieben
# 16243000 embeddings geschrieben
# 16243500 embeddings geschrieben
# 16244000 embeddings geschrieben
# 16244500 embeddings geschrieben
# 16245000 embeddings geschrieben
# 16245500 embeddings geschrieben
# 16246000 embeddings geschrieben
# 16246500 embeddings geschrieben
# 16247000 embeddings geschrieben
# 16247500 embeddings geschrieben
# 16248000 embeddings geschrieben
# 16248500 embeddings geschrieben
# 16249000 embeddings geschrieben
# 16249500 embeddings geschrieben
# 16250000 embeddings geschrieben
# 16250500 embeddings geschrieben
# 16251000 embeddings geschrieben
# 16251500 embeddings geschrieben
# 16252000 embeddings geschrieben
# 16252500 embeddings geschrieben
# 16253000 embeddings geschrieben
# 16253500 embeddings geschrieben
# 16254000 embeddings geschrieben
# 16254500 embeddings geschrieben
# 16255000 embeddings geschrieben
# 16255500 embeddings geschrieben
# 16256000 embeddings geschrieben
# 16256500 embeddings geschrieben
# 16257000 embeddings geschrieben
# 16257500 embeddings geschrieben
# 16258000 embeddings geschrieben
# 16258500 embeddings geschrieben
# 16259000 embeddings geschrieben
# 16259500 embeddings geschrieben
# 16260000 embeddings geschrieben
# 16260500 embeddings geschrieben
# 16261000 embeddings geschrieben
# 16261500 embeddings geschrieben
# 16262000 embeddings geschrieben
# 16262500 embeddings geschrieben
# 16263000 embeddings geschrieben
# 16263500 embeddings geschrieben
# 16264000 embeddings geschrieben
# 16264500 embeddings geschrieben
# 16265000 embeddings geschrieben
# 16265500 embeddings geschrieben
# 16266000 embeddings geschrieben
# 16266500 embeddings geschrieben
# 16267000 embeddings geschrieben
# 16267500 embeddings geschrieben
# 16268000 embeddings geschrieben
# 16268500 embeddings geschrieben
# 16269000 embeddings geschrieben
# 16269500 embeddings geschrieben
# 16270000 embeddings geschrieben
# 16270500 embeddings geschrieben
# 16271000 embeddings geschrieben
# 16271500 embeddings geschrieben
# 16272000 embeddings geschrieben
# 16272500 embeddings geschrieben
# 16273000 embeddings geschrieben
# 16273500 embeddings geschrieben
# 16274000 embeddings geschrieben
# 16274500 embeddings geschrieben
# 16275000 embeddings geschrieben
# 16275500 embeddings geschrieben
# 16276000 embeddings geschrieben
# 16276500 embeddings geschrieben
# 16277000 embeddings geschrieben
# 16277500 embeddings geschrieben
# 16278000 embeddings geschrieben
# 16278500 embeddings geschrieben
# 16279000 embeddings geschrieben
# 16279500 embeddings geschrieben
# 16280000 embeddings geschrieben
# 16280500 embeddings geschrieben
# 16281000 embeddings geschrieben
# 16281500 embeddings geschrieben
# 16282000 embeddings geschrieben
# 16282500 embeddings geschrieben
# 16283000 embeddings geschrieben
# 16283500 embeddings geschrieben
# 16284000 embeddings geschrieben
# 16284500 embeddings geschrieben
# 16285000 embeddings geschrieben
# 16285500 embeddings geschrieben
# 16286000 embeddings geschrieben
# 16286500 embeddings geschrieben
# 16287000 embeddings geschrieben
# 16287500 embeddings geschrieben
# 16288000 embeddings geschrieben
# 16288500 embeddings geschrieben
# 16289000 embeddings geschrieben
# 16289500 embeddings geschrieben
# 16290000 embeddings geschrieben
# 16290500 embeddings geschrieben
# 16291000 embeddings geschrieben
# 16291500 embeddings geschrieben
# 16292000 embeddings geschrieben
# 16292500 embeddings geschrieben
# 16293000 embeddings geschrieben
# 16293500 embeddings geschrieben
# 16294000 embeddings geschrieben
# 16294500 embeddings geschrieben
# 16295000 embeddings geschrieben
# 16295500 embeddings geschrieben
# 16296000 embeddings geschrieben
# 16296500 embeddings geschrieben
# 16297000 embeddings geschrieben
# 16297500 embeddings geschrieben
# 16298000 embeddings geschrieben
# 16298500 embeddings geschrieben
# 16299000 embeddings geschrieben
# 16299500 embeddings geschrieben
# 16300000 embeddings geschrieben
# 16300500 embeddings geschrieben
# 16301000 embeddings geschrieben
# 16301500 embeddings geschrieben
# 16302000 embeddings geschrieben
# 16302500 embeddings geschrieben
# 16303000 embeddings geschrieben
# 16303500 embeddings geschrieben
# 16304000 embeddings geschrieben
# 16304500 embeddings geschrieben
# 16305000 embeddings geschrieben
# 16305500 embeddings geschrieben
# 16306000 embeddings geschrieben
# 16306500 embeddings geschrieben
# 16307000 embeddings geschrieben
# 16307500 embeddings geschrieben
# 16308000 embeddings geschrieben
# 16308500 embeddings geschrieben
# 16309000 embeddings geschrieben
# 16309500 embeddings geschrieben
# 16310000 embeddings geschrieben
# 16310500 embeddings geschrieben
# 16311000 embeddings geschrieben
# 16311500 embeddings geschrieben
# 16312000 embeddings geschrieben
# 16312500 embeddings geschrieben
# 16313000 embeddings geschrieben
# 16313500 embeddings geschrieben
# 16314000 embeddings geschrieben
# 16314500 embeddings geschrieben
# 16315000 embeddings geschrieben
# 16315500 embeddings geschrieben
# 16316000 embeddings geschrieben
# 16316500 embeddings geschrieben
# 16317000 embeddings geschrieben
# 16317500 embeddings geschrieben
# 16318000 embeddings geschrieben
# 16318500 embeddings geschrieben
# 16319000 embeddings geschrieben
# 16319500 embeddings geschrieben
# 16320000 embeddings geschrieben
# 16320500 embeddings geschrieben
# 16321000 embeddings geschrieben
# 16321500 embeddings geschrieben
# 16322000 embeddings geschrieben
# 16322500 embeddings geschrieben
# 16323000 embeddings geschrieben
# 16323500 embeddings geschrieben
# 16324000 embeddings geschrieben
# 16324500 embeddings geschrieben
# 16325000 embeddings geschrieben
# 16325500 embeddings geschrieben
# 16326000 embeddings geschrieben
# 16326500 embeddings geschrieben
# 16327000 embeddings geschrieben
# 16327500 embeddings geschrieben
# 16328000 embeddings geschrieben
# 16328500 embeddings geschrieben
# 16329000 embeddings geschrieben
# 16329500 embeddings geschrieben
# 16330000 embeddings geschrieben
# 16330500 embeddings geschrieben
# 16331000 embeddings geschrieben
# 16331500 embeddings geschrieben
# 16332000 embeddings geschrieben
# 16332500 embeddings geschrieben
# 16333000 embeddings geschrieben
# 16333500 embeddings geschrieben
# 16334000 embeddings geschrieben
# 16334500 embeddings geschrieben
# 16335000 embeddings geschrieben
# 16335500 embeddings geschrieben
# 16336000 embeddings geschrieben
# 16336500 embeddings geschrieben
# 16337000 embeddings geschrieben
# 16337500 embeddings geschrieben
# 16338000 embeddings geschrieben
# 16338500 embeddings geschrieben
# 16339000 embeddings geschrieben
# 16339500 embeddings geschrieben
# 16340000 embeddings geschrieben
# 16340500 embeddings geschrieben
# 16341000 embeddings geschrieben
# 16341500 embeddings geschrieben
# 16342000 embeddings geschrieben
# 16342500 embeddings geschrieben
# 16343000 embeddings geschrieben
# 16343500 embeddings geschrieben
# 16344000 embeddings geschrieben
# 16344500 embeddings geschrieben
# 16345000 embeddings geschrieben
# 16345500 embeddings geschrieben
# 16346000 embeddings geschrieben
# 16346500 embeddings geschrieben
# 16347000 embeddings geschrieben
# 16347500 embeddings geschrieben
# 16348000 embeddings geschrieben
# 16348500 embeddings geschrieben
# 16349000 embeddings geschrieben
# 16349500 embeddings geschrieben
# 16350000 embeddings geschrieben
# 16350500 embeddings geschrieben
# 16351000 embeddings geschrieben
# 16351500 embeddings geschrieben
# 16352000 embeddings geschrieben
# 16352500 embeddings geschrieben
# 16353000 embeddings geschrieben
# 16353500 embeddings geschrieben
# 16354000 embeddings geschrieben
# 16354500 embeddings geschrieben
# 16355000 embeddings geschrieben
# 16355500 embeddings geschrieben
# 16356000 embeddings geschrieben
# 16356500 embeddings geschrieben
# 16357000 embeddings geschrieben
# 16357500 embeddings geschrieben
# 16358000 embeddings geschrieben
# 16358500 embeddings geschrieben
# 16359000 embeddings geschrieben
# 16359500 embeddings geschrieben
# 16360000 embeddings geschrieben
# 16360500 embeddings geschrieben
# 16361000 embeddings geschrieben
# 16361500 embeddings geschrieben
# 16362000 embeddings geschrieben
# 16362500 embeddings geschrieben
# 16363000 embeddings geschrieben
# 16363500 embeddings geschrieben
# 16364000 embeddings geschrieben
# 16364500 embeddings geschrieben

# %% [markdown]
# #Start

# %%
projection_query_start  = """
MATCH (source)-[r:HAS_START|HAS_END]->(target)
WHERE source:Trip AND target:Station
WITH gds.graph.project(
  'externalGraph',
  source,
  target,
  {
    sourceNodeProperties: source {
      externalTimeEmbeddingStart: source.startTimeEmbedding
    },
    targetNodeProperties: target {
     externalTimeEmbeddingStart: target.startTimeEmbedding
    }},
  {undirectedRelationshipTypes: ['*']}
) AS g
RETURN g.graphName AS graph, g.nodeCount AS nodes, g.relationshipCount AS rels
"""

# %%
#4min40s
with db_driver.session(database=database) as session:
        session.run(projection_query_start)

# %%
G = gds.graph.get("externalGraph")

# %%
gds.fastRP.write.estimate(
    G,
    writeProperty="externalEmbeddingStart",
    randomSeed = 42,
    embeddingDimension= 128,
    nodeSelfInfluence = 1.0,
    propertyRatio = 0.5,
    featureProperties = ['externalTimeEmbeddingStart'],
    iterationWeights = [1.0]
)
# Out:
# requiredMemory                                                  24 GiB
# treeView             Memory Estimation: 24 GiB\n|-- algorithm: 24 G...
# mapView              {'memoryUsage': '24 GiB', 'name': 'Memory Esti...
# bytesMin                                                   26708600512
# bytesMax                                                   26708600512
# nodeCount                                                     16365505
# relationshipCount                                             65480276
# heapPercentageMin                                                  0.8
# heapPercentageMax                                                  0.8
# Name: 0, dtype: object

# %%
#19min
gds.fastRP.write(
    G,
    writeProperty="externalEmbeddingStart",
    randomSeed = 42,
    embeddingDimension= 128,
    nodeSelfInfluence = 1.0,
    propertyRatio = 0.5,
    featureProperties = ['externalTimeEmbeddingStart'],
    iterationWeights = [1.0]
)
# Out:
#  FastRP:   0%|          | 0/100 [00:00<?, ?%/s]
# nodeCount                                                         16365505
# nodePropertiesWritten                                             16365505
# preProcessingMillis                                                      0
# computeMillis                                                        28657
# writeMillis                                                         305952
# configuration            {'writeProperty': 'externalEmbeddingStart', 'r...
# Name: 0, dtype: object

# %%
G.drop()
# Out:
# graphName                                                    externalGraph
# database                                                             neo4j
# databaseLocation                                                     local
# memoryUsage
# sizeInBytes                                                             -1
# nodeCount                                                         16365505
# relationshipCount                                                 65480276
# configuration            {'readConcurrency': 4, 'undirectedRelationship...
# density                                                                0.0
# creationTime                           2025-04-18T14:02:08.899277000+02:00
# modificationTime                       2025-04-18T14:02:08.899277000+02:00
# schema                   {'graphProperties': {}, 'nodes': {'__ALL__': {...
# schemaWithOrientation    {'graphProperties': {}, 'nodes': {'__ALL__': {...
# Name: 0, dtype: object

# %% [markdown]
# #End

# %%
projection_query_end  = """
MATCH (source)-[r:HAS_START|HAS_END]->(target)
WHERE source:Trip AND target:Station
WITH gds.graph.project(
  'externalGraph',
  source,
  target,
  {
    sourceNodeProperties: source {
      externalTimeEmbeddingEnd: source.endTimeEmbedding
    },
    targetNodeProperties: target {
     externalTimeEmbeddingEnd: target.endTimeEmbedding
    }},
  {undirectedRelationshipTypes: ['*']}
) AS g
RETURN g.graphName AS graph, g.nodeCount AS nodes, g.relationshipCount AS rels
"""

# %%
with db_driver.session(database=database) as session:
        session.run(projection_query_end)

# %%
G = gds.graph.get("externalGraph")

# %%
gds.fastRP.write.estimate(
    G,
    writeProperty="externalEmbeddingEnd",
    randomSeed = 42,
    embeddingDimension= 128,
    nodeSelfInfluence = 1.0,
    propertyRatio = 0.5,
    featureProperties = ['externalTimeEmbeddingEnd'],
    iterationWeights = [1.0]
)
# Out:
# requiredMemory                                                  24 GiB
# treeView             Memory Estimation: 24 GiB\n|-- algorithm: 24 G...
# mapView              {'memoryUsage': '24 GiB', 'name': 'Memory Esti...
# bytesMin                                                   26708600512
# bytesMax                                                   26708600512
# nodeCount                                                     16365505
# relationshipCount                                             65480276
# heapPercentageMin                                                  0.8
# heapPercentageMax                                                  0.8
# Name: 0, dtype: object

# %%
#16min
gds.fastRP.write(
    G,
    writeProperty="externalEmbeddingEnd",
    randomSeed = 42,
    embeddingDimension= 128,
    nodeSelfInfluence = 1.0,
    propertyRatio = 0.5,
    featureProperties = ['externalTimeEmbeddingEnd'],
    iterationWeights = [1.0]
)
# Out:
#  FastRP:   0%|          | 0/100 [00:00<?, ?%/s]
# nodeCount                                                         16365505
# nodePropertiesWritten                                             16365505
# preProcessingMillis                                                      0
# computeMillis                                                        27775
# writeMillis                                                         971161
# configuration            {'writeProperty': 'externalEmbeddingEnd', 'ran...
# Name: 0, dtype: object

# %%
G.drop()
# Out:
# graphName                                                    externalGraph
# database                                                             neo4j
# databaseLocation                                                     local
# memoryUsage
# sizeInBytes                                                             -1
# nodeCount                                                         16365505
# relationshipCount                                                 65480276
# configuration            {'readConcurrency': 4, 'undirectedRelationship...
# density                                                                0.0
# creationTime                           2025-04-18T14:25:37.376512000+02:00
# modificationTime                       2025-04-18T14:25:37.376512000+02:00
# schema                   {'graphProperties': {}, 'nodes': {'__ALL__': {...
# schemaWithOrientation    {'graphProperties': {}, 'nodes': {'__ALL__': {...
# Name: 0, dtype: object

# %% [markdown]
# Hier kommt jetzt averagen der beiden embeddings und dann index rauf

# %%
#9min
average_query = """
CALL apoc.periodic.iterate(
  "MATCH (t:Trip) WHERE t.externalTimeEmbeddingStart IS NOT NULL AND t.externalTimeEmbeddingEnd IS NOT NULL RETURN t",
  "WITH t, apoc.coll.zip(t.externalEmbeddingStart, t.externalEmbeddingEnd) AS zipped
   SET t.externalIntervalEmbedding = [pair IN zipped | (pair[0] + pair[1]) / 2.0]",
  {batchSize:10000, parallel:true}
)"""

with db_driver.session() as session:
    session.run(average_query)

# %%
def create_vector_index(index_name, label, property_name, vector_dimension, similarity="cosine"):
    query = f"""
    CREATE VECTOR INDEX {index_name} IF NOT EXISTS
    FOR (n:{label})
    ON (n.{property_name})
    OPTIONS {{
    indexConfig: {{
        `vector.dimensions`: {vector_dimension},
        `vector.similarity_function`: '{similarity}'
        }}
    }}
    """
    with db_driver.session(database=database) as session:
        session.run(query)
create_vector_index( 'externalIntervalIndex','Trip', 'externalIntervalEmbedding', '128')

# %%
gds.close()
db_driver.close()
